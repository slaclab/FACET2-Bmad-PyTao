# %%
from UTILITY_quickstart import *

importedDefaultSettings = loadConfig("setLattice_configs/2024-10-22_oneBunch_baseline2.yml")

tao = initializeTao(
    inputBeamFilePathSuffix = importedDefaultSettings["inputBeamFilePathSuffix"],   
    csrTF = True,
    numMacroParticles=1e4
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR on
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using setLattice_configs/defaults.yml
# Number of macro particles = 10000.0
# Beam created, written to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/beams/activeBeamFile.h5, and reinit to tao

# %%
setLattice(tao, **(importedDefaultSettings | {"L1PhaseSet" : -10, "L2PhaseSet" : -7, "L3PhaseSet" : -7}))
trackBeam(tao, **importedDefaultSettings)

# %%
P = getBeamAtElement(tao, "ENDBC11_2")
print("ENDBC11")
display(plotMod(P, 'z', 'energy', bins=300))
print(smallestInterval(P.energy) / 1e6)

P = getBeamAtElement(tao, "BEGBC14_1")
print("BEGBC14")
display(plotMod(P, 'z', 'energy', bins=300))
print(smallestInterval(P.energy) / 1e6)

P = getBeamAtElement(tao, "ENDBC14_2")
print("ENDBC14")
display(plotMod(P, 'z', 'energy', bins=300))
print(smallestInterval(P.energy) / 1e6)

P = getBeamAtElement(tao, "BEGBC20")
print("BEGBC20")
display(plotMod(P, 'z', 'energy', bins=300))
print(smallestInterval(P.energy) / 1e6)


plt.clf()
# Out:
# ENDBC11
# 0.5553629629935622
# BEGBC14
# 4.458370764110565
# ENDBC14
# 4.306057895902634
# BEGBC20
# 7.350173898036957
