# %%
from UTILITY_quickstart import *
tao = initializeTao()
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-S2E
# CSR off
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using /Users/nmajik/Documents/SLAC/FACET2-S2E/setLattice_configs/defaults.yml
# WARNING! No beam file is specified!
# Number of macro particles defined by input file
# Beam created, written to /Users/nmajik/Documents/SLAC/FACET2-S2E/beams/activeBeamFile.h5, and reinit to tao

# %%
floorplanPlot(tao)

# %%
floorplanPlot(tao, zmin = 975)

# %%
tao.cmd("show ele YC2FF")
# Out:
# ['Element # 1488',
#  'Element Name: YC2FF',
#  'Element Type:  "3D8.8MK2"',
#  'Key: VKicker',
#  'S_start, S:    983.555764,    983.555764',
#  'Ref_time_start, Ref_time:  3.280806E-06,  3.280806E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  9.9984356E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  9.9984356E+09 eV           GAMMA                       =  1.9566450E+04',
#  '   64  REF_TIME_START              =  3.2808059E-06 sec      50  DELTA_REF_TIME              =  0.0000000E+00 sec',
#  '   67  DS_STEP                     =  2.0000000E-01 m        66  NUM_STEPS                   = 1',
#  '',
# ...

# %%
tao.twiss_at_s(ele = "YC2FF", s_offset = -0.3)
# Out:
# {'beta_a': 59.8514224470173,
#  'alpha_a': -1.31518677840006,
#  'gamma_a': 0.0456082103060255,
#  'phi_a': 71.504372675399,
#  'eta_a': 6.13520630663061e-05,
#  'etap_a': 3.45140107295462e-07,
#  'beta_b': 1.60478203032044,
#  'alpha_b': 0.704197547913124,
#  'gamma_b': 0.932147891877975,
#  'phi_b': 56.9927709546185,
#  'eta_b': 8.52129026565821e-18,
#  'etap_b': 1.76101444927167e-20,
#  'c_mat11': -1.17146567645019e-16,
#  'c_mat12': -1.17058746476746e-17,
#  'c_mat21': -1.60711481840732e-17,
#  'c_mat22': 1.39750823343821e-18,
#  'gamma_c': 1.0}
