# %%
from UTILITY_quickstart import *

importedDefaultSettings = loadConfig("setLattice_configs/2024-10-22_oneBunch_2025-02-14-14-42-01.yml")

tao = initializeTao(
    inputBeamFilePathSuffix = importedDefaultSettings["inputBeamFilePathSuffix"],   
    csrTF = True,
    #numMacroParticles=1e4
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR on
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using setLattice_configs/defaults.yml
# Number of macro particles defined by input file
# Beam created, written to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/beams/activeBeamFile.h5, and reinit to tao

# %% [markdown]
# ## BC20 high compression

# %%
setLattice(tao, **importedDefaultSettings)
trackBeam(tao, **importedDefaultSettings)

# %%
P = getBeamAtElement(tao, "PENT")

display(plotMod(P, 'delta_t', 'pz', bins=300))
plt.clf()

# %% [markdown]
# ## BC14 high compression

# %%
setLattice(tao, **(importedDefaultSettings | {"L1PhaseSet" : -22, "L2PhaseSet" : -35.7}))
trackBeam(tao, trackEnd = "ENDBC14_2", **importedDefaultSettings)

# %%
P = getBeamAtElement(tao, "ENDBC14_2")

display(plotMod(P, 'delta_t', 'pz', bins=300))
plt.clf()
