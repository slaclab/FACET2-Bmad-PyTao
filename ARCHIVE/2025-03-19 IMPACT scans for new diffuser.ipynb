# %%
from UTILITY_quickstart import *

# %%
# tao = initializeTao(
#     #inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
#     # defaultsFile = "setLattice_defaults_2024-08-21_demo.yml",
#     # csrTF = True,
#     #numMacroParticles = 1e3,
#     loadDefaultLatticeTF = False
# )

# %%
from datetime import datetime

def get_current_time_formatted():
    return datetime.now().strftime("%Y-%m-%d-%H-%M-%S")

exportFileName = f"impactResults_{get_current_time_formatted()}.json"

# %% [markdown]
# ## Solenoid scan

# %%
history = pd.DataFrame()

solSet = -0.41
impactGridCount = 25 #2025-03-20: 20 doesn't seem to be quite converged, but appears good to within ~5%
L0APhaseOffset = 0


#for impactGridCount in [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70]:
for solSet in np.arange(-0.37, -0.43, -0.005): #-0.005
#   for L0APhaseOffset in np.arange(-15, 20, 5): 


    savedData = {}
    
    print(f"Solenoid: {solSet}")
    
    I = runImpact(
        impactGridCount = impactGridCount, #E. Cropp suggests setting such that 5 = ppc = N / grids^3
        #numMacroParticles = 1e5,
        numMacroParticles = 5 * impactGridCount ** 3, 
        GFILESuffix = '2025-03-19_distgen_onebunch.yaml',
        L0APhaseOffset = L0APhaseOffset,
        solenoidTValue = solSet,
        returnImpactObject = True
    )

    
    #P = I.particles['PR10241'].copy()
    P = I.particles['L0AFEND'].copy()

    # P = nudgeMacroparticleWeights(
    #     P,
    #     trailingBunchFraction = 0.75,
    #     trailingBunchType = "driver"
    # )
    
    # PDrive, PWitness = getDriverAndWitness(P)
    
    display(plotMod(P, 'x', 'y',  bins=100))
    display(plotMod(P, 'x', 'xp', bins=100))
    display(plotMod(P, 'delta_z', 'energy', bins=100))

    savedData["L0APhaseOffset"] = L0APhaseOffset
    savedData["solSet"] = solSet
    savedData["impactGridCount"] = impactGridCount

    #This actually seems survive export to JSON. Makes big files though
    #savedData["P"] = P 
    
    savedData["norm_emit_x"] = P.norm_emit_x
    savedData["norm_emit_y"] = P.norm_emit_y

    savedData["norm_emit_x_90"] = (P.twiss(plane = "x", fraction = 0.9))["norm_emit_x"]
    savedData["norm_emit_y_90"] = (P.twiss(plane = "y", fraction = 0.9))["norm_emit_y"]

    savedData["emitSI90_x"] = smallestIntervalImpliedEmittance(P, plane = "x", percentage = 0.90)
    savedData["emitSI90_y"] = smallestIntervalImpliedEmittance(P, plane = "y", percentage = 0.90)


    

    # savedData["PDrive_emitSI90_x"] = smallestIntervalImpliedEmittance(PDrive, plane = "x", percentage = 0.90)
    # savedData["PDrive_emitSI90_y"] = smallestIntervalImpliedEmittance(PDrive, plane = "y", percentage = 0.90)

    # savedData["PWitness_emitSI90_x"] = smallestIntervalImpliedEmittance(PWitness, plane = "x", percentage = 0.90)
    # savedData["PWitness_emitSI90_y"] = smallestIntervalImpliedEmittance(PWitness, plane = "y", percentage = 0.90)

    # savedData["PDrive_charge"] = PDrive.charge
    # savedData["PWitness_charge"] = PWitness.charge

    # savedData[f"sigmaSI90_x"] = smallestIntervalImpliedSigma(P.x, percentage = 0.90)
    # savedData[f"sigmaSI90_y"] = smallestIntervalImpliedSigma(P.y, percentage = 0.90)

    # print(f"""{savedData["norm_emit_x"]}, {savedData["norm_emit_y"]}""")
    # print(f"""{savedData["emitSI90_x"]}, {savedData["emitSI90_y"]}""")

    print(savedData)
    
    tmpData = pd.Series( savedData ) 
    history = pd.concat([history, tmpData.to_frame().T])

    history.to_json(exportFileName, orient='records')
# Out:
# Solenoid: -0.37
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpim7vvd0l
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpim7vvd0l/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 403.4512948989868Finished.5161, elapsed: 403.2797250747680765015
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# {'L0APhaseOffset': 0, 'solSet': -0.37, 'impactGridCount': 25, 'norm_emit_x': 7.114507138018495e-06, 'norm_emit_y': 7.117218293216295e-06, 'norm_emit_x_90': 2.992989247663608e-06, 'norm_emit_y_90': 2.996305170390492e-06, 'emitSI90_x': 5.10489159464217e-06, 'emitSI90_y': 5.2765809358998704e-06}
# Solenoid: -0.375
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpx0twru3v
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpx0twru3v/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 400.51765298843384Finished.971, elapsed: 400.3477120399475670996
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# {'L0APhaseOffset': 0, 'solSet': -0.375, 'impactGridCount': 25, 'norm_emit_x': 6.676913721279884e-06, 'norm_emit_y': 6.681547789147597e-06, 'norm_emit_x_90': 2.6246516620267275e-06, 'norm_emit_y_90': 2.625541531263931e-06, 'emitSI90_x': 4.488639418507901e-06, 'emitSI90_y': 4.560625892378874e-06}
# Solenoid: -0.38
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpmv66x5u4
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpmv66x5u4/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 411.605988740921Finished.84033, elapsed: 411.4349708557129654895
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# {'L0APhaseOffset': 0, 'solSet': -0.38, 'impactGridCount': 25, 'norm_emit_x': 6.217353923406075e-06, 'norm_emit_y': 6.226159733725924e-06, 'norm_emit_x_90': 2.3303717300527086e-06, 'norm_emit_y_90': 2.329601043412205e-06, 'emitSI90_x': 3.6115162045769336e-06, 'emitSI90_y': 3.677221057168231e-06}
# Solenoid: -0.385
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmprk4nymb0
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmprk4nymb0/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 401.71057510375977Finished.006, elapsed: 401.5309381484985420056
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# {'L0APhaseOffset': 0, 'solSet': -0.385, 'impactGridCount': 25, 'norm_emit_x': 5.787719484340551e-06, 'norm_emit_y': 5.798531507199863e-06, 'norm_emit_x_90': 2.1968605717690728e-06, 'norm_emit_y_90': 2.1991632588537478e-06, 'emitSI90_x': 3.2766339278224347e-06, 'emitSI90_y': 3.1478745657719993e-06}
# Solenoid: -0.39
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmp6qmt0yao
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmp6qmt0yao/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 411.3842828273773Finished.1291, elapsed: 411.2150211334228549011
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# {'L0APhaseOffset': 0, 'solSet': -0.39, 'impactGridCount': 25, 'norm_emit_x': 5.46204645750707e-06, 'norm_emit_y': 5.469021574093378e-06, 'norm_emit_x_90': 2.2365214715596636e-06, 'norm_emit_y_90': 2.2402209300619766e-06, 'emitSI90_x': 3.8101906269038926e-06, 'emitSI90_y': 3.948940462213812e-06}
# Solenoid: -0.395
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpfj28d_em
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpfj28d_em/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 404.9708731174469Finished.8632, elapsed: 404.7954699993133528918
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# {'L0APhaseOffset': 0, 'solSet': -0.395, 'impactGridCount': 25, 'norm_emit_x': 5.1825462720086966e-06, 'norm_emit_y': 5.172712798521094e-06, 'norm_emit_x_90': 2.2873368795998757e-06, 'norm_emit_y_90': 2.2846363920378467e-06, 'emitSI90_x': 3.889109682712683e-06, 'emitSI90_y': 3.8058024015674805e-06}
# Solenoid: -0.4
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpw4s5rj09
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpw4s5rj09/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 400.8899669647217Finished.8680, elapsed: 400.7152810096741799231
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py:498: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(sigmax**2 + 2 * z * rho * sigmax * sigmaxp + z**2 * sigmaxp**2)
# {'L0APhaseOffset': 0, 'solSet': -0.4, 'impactGridCount': 25, 'norm_emit_x': 4.799427094965865e-06, 'norm_emit_y': 4.790359659715153e-06, 'norm_emit_x_90': 2.1730685213596e-06, 'norm_emit_y_90': 2.168781659285682e-06, 'emitSI90_x': 3.915931524608208e-06, 'emitSI90_y': 3.68779297259156e-06}
# Solenoid: -0.405
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpvs748_jl
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpvs748_jl/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 403.7012939453125Finished.5435, elapsed: 403.5299708843231653345
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py:498: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(sigmax**2 + 2 * z * rho * sigmax * sigmaxp + z**2 * sigmaxp**2)
# {'L0APhaseOffset': 0, 'solSet': -0.405, 'impactGridCount': 25, 'norm_emit_x': 4.550837458301244e-06, 'norm_emit_y': 4.5445994409635535e-06, 'norm_emit_x_90': 1.8962051095083747e-06, 'norm_emit_y_90': 1.894029394932463e-06, 'emitSI90_x': 2.7378202334555715e-06, 'emitSI90_y': 3.0284365417201122e-06}
# Solenoid: -0.41000000000000003
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpxyr6vmw2
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpxyr6vmw2/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 402.4053041934967Finished.9858, elapsed: 402.2288193702698390784
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py:498: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(sigmax**2 + 2 * z * rho * sigmax * sigmaxp + z**2 * sigmaxp**2)
# {'L0APhaseOffset': 0, 'solSet': -0.41000000000000003, 'impactGridCount': 25, 'norm_emit_x': 5.5520455214026725e-06, 'norm_emit_y': 5.5471671385943436e-06, 'norm_emit_x_90': 1.9317185196975846e-06, 'norm_emit_y_90': 1.933105802277937e-06, 'emitSI90_x': 2.8690152643595755e-06, 'emitSI90_y': 3.022832062858998e-06}
# Solenoid: -0.41500000000000004
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpd5z0ki7w
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpd5z0ki7w/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 405.11686182022095Finished.077, elapsed: 404.9378616809845507324
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py:498: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(sigmax**2 + 2 * z * rho * sigmax * sigmaxp + z**2 * sigmaxp**2)
# {'L0APhaseOffset': 0, 'solSet': -0.41500000000000004, 'impactGridCount': 25, 'norm_emit_x': 8.510926581218323e-06, 'norm_emit_y': 8.511100001447167e-06, 'norm_emit_x_90': 2.749550276597163e-06, 'norm_emit_y_90': 2.748473732738099e-06, 'emitSI90_x': 4.933832320655711e-06, 'emitSI90_y': 4.9252231227915935e-06}
# Solenoid: -0.42000000000000004
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmppms5sl3g
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmppms5sl3g/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 402.55388736724854Finished.297, elapsed: 402.3728082180023340719
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py:498: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(sigmax**2 + 2 * z * rho * sigmax * sigmaxp + z**2 * sigmaxp**2)
# {'L0APhaseOffset': 0, 'solSet': -0.42000000000000004, 'impactGridCount': 25, 'norm_emit_x': 1.2717175006560994e-05, 'norm_emit_y': 1.2726322469184347e-05, 'norm_emit_x_90': 4.205824008815308e-06, 'norm_emit_y_90': 4.209964938381759e-06, 'emitSI90_x': 7.634534720770604e-06, 'emitSI90_y': 7.869377291448025e-06}
# Solenoid: -0.42500000000000004
# Running Impact
# Assuming default file path: /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# 	 Impact: Autophasing
# 	 Impact: Distgen
# 	 Impact: Tracking
# Running Impact-T in /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpjqqr9w6m
# /opt/homebrew/anaconda3/envs/bmad/bin/ImpactTexe
# writing 78125 particles to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/impact/tmpjqqr9w6m/partcl.data
# Cathode start with cathode_kinetic_energy_ref = 1.0 eV
# Cathode start: Replaced Np with 78125 according to initial particles
# Cathode start: Replaced Bkenergy with 1.0 according to initial particles
# Cathode start: Replaced Temission with 7.014492708801321e-12 according to initial particles
# Cathode start: Replaced Tini with -3.5085739089442386e-12 according to initial particles
# Setting total charge to 1.5999999999999999e-09 C
#  !-----------------------------------------------------------
#  ! IMPACT-T Parallel Beam Dynamics Tracking Code: V2.3.1
#  ! Copyright of The Regents of the University of California
#  !-----------------------------------------------------------
#  nblem:           28          28
#  pass setting up lattice...
#  check randomness:            0  0.30440529327431320
#  avgpts, jlow, and jhigh:        78125           1       78125
#  sumx1,sumy1:    2.0324908422963970E-018  -6.2768130100711231E-018
#  pass generating initial distribution...
#  tstop:    4.2000000000000002
#  i,t,<z>:            1  -3.5085739089442386E-012   0.0000000000000000
#  zmin,zmax:   -4.1602681846924651E-006  -1.0164395367051603E-020
#  i,t,<z>:            2  -3.4910376771722356E-012  -2.0809214597526073E-006
#  time:    0.0000000000000000, elapsed: 401.74823808670044Finished.901, elapsed: 401.5717291831970651538
# Loaded fort 30 : Fourth root of the fourth moments of the beam distribution
# Loaded fort 25 : RMS Y information
# Loaded fort 24 : RMS X information
# Loaded fort 26 : RMS Z information
# Loaded fort 28 : Load balance and loss diagnostics
# Loaded fort 29 : Cube root of third moments of the beam distribution
# Loaded fort 18 : Time and energy
# Loaded fort 27 : Max amplitude information
# Loaded fort 70 : Slice information of the final distribution
# Loaded fort 60 : Slice information of the initial distribution
# Loading particles
# Loaded fort 40 : initial particle distribution at t = 0
# Loaded fort 50 : final particle distribution projected to the centroid location of the bunch
# Loaded write beam particles PR10241 fort.102
# Loaded write beam particles L0AFEND fort.103
# Converting z to t according to cathode_kinetic_energy_ref = 1.0 eV
# Converted initial_particles to ParticleGroup
# Converted final_particles to ParticleGroup
# Converted PR10241 to ParticleGroup
# Converted L0AFEND to ParticleGroup
# /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py:498: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(sigmax**2 + 2 * z * rho * sigmax * sigmaxp + z**2 * sigmaxp**2)
# {'L0APhaseOffset': 0, 'solSet': -0.42500000000000004, 'impactGridCount': 25, 'norm_emit_x': 1.733983022166979e-05, 'norm_emit_y': 1.7358916221903585e-05, 'norm_emit_x_90': 6.165847812256068e-06, 'norm_emit_y_90': 6.192218014054621e-06, 'emitSI90_x': 9.590085181249324e-06, 'emitSI90_y': 9.418594569585398e-06}

# %%
#history

# %% [markdown]
# ## Final export

# %%
# history = pd.DataFrame()

# solSet = -0.41
# impactGridCount = 100 #100


# savedData = {}

# print(f"Solenoid: {solSet}")

# I = runImpact(
#     impactGridCount = impactGridCount, #E. Cropp suggests setting such that 5 = ppc = N / grids^3
#     numMacroParticles = 1e6,
#     GFILESuffix = '2024-10-22_distgen_onebunch.yaml',
#     L0APhaseOffset = 0,
#     solenoidTValue = solSet,
#     returnImpactObject = True
# )


# #P = I.particles['PR10241'].copy()
# P = I.particles['L0AFEND'].copy()

# %%
# display(plotMod(P, 'x', 'y',  bins=100))
# display(plotMod(P, 'x', 'xp', bins=100))
# display(plotMod(P, 'delta_z', 'energy', bins=100))
# plt.clf()

# %%
# P.drift_to_z()
# P.write("2024-10-22_oneBunch.h5")

# %% [markdown]
# ####
